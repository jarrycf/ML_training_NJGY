# %%
# !pip install "mxnet<2.0.0"
# Out:
# Collecting mxnet<2.0.0
#   Downloading mxnet-1.6.0-py2.py3-none-any.whl (68.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.7/68.7 MB 14.1 MB/s eta 0:00:00m eta 0:00:010:00:01
# Collecting graphviz<0.9.0,>=0.8.1
#   Downloading graphviz-0.8.4-py2.py3-none-any.whl (16 kB)
# Requirement already satisfied: requests<3,>=2.20.0 in /Users/jarrycf/opt/anaconda3/lib/python3.9/site-packages (from mxnet<2.0.0) (2.28.1)
# Requirement already satisfied: numpy<2.0.0,>1.16.0 in /Users/jarrycf/opt/anaconda3/lib/python3.9/site-packages (from mxnet<2.0.0) (1.21.5)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/jarrycf/opt/anaconda3/lib/python3.9/site-packages (from requests<3,>=2.20.0->mxnet<2.0.0) (2022.9.24)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/jarrycf/opt/anaconda3/lib/python3.9/site-packages (from requests<3,>=2.20.0->mxnet<2.0.0) (1.26.11)
# Requirement already satisfied: idna<4,>=2.5 in /Users/jarrycf/opt/anaconda3/lib/python3.9/site-packages (from requests<3,>=2.20.0->mxnet<2.0.0) (3.3)
# Requirement already satisfied: charset-normalizer<3,>=2 in /Users/jarrycf/opt/anaconda3/lib/python3.9/site-packages (from requests<3,>=2.20.0->mxnet<2.0.0) (2.0.4)
# Installing collected packages: graphviz, mxnet
# Successfully installed graphviz-0.8.4 mxnet-1.6.0

# %%
! pip install autogluon
# Out:
# Collecting autogluon
#   Using cached autogluon-0.6.0-py3-none-any.whl (9.8 kB)
# Collecting autogluon.core[all]==0.6.0
#   Using cached autogluon.core-0.6.0-py3-none-any.whl (224 kB)
# Collecting autogluon.timeseries[all]==0.6.0
#   Using cached autogluon.timeseries-0.6.0-py3-none-any.whl (101 kB)
# Collecting autogluon.vision==0.6.0
#   Using cached autogluon.vision-0.6.0-py3-none-any.whl (49 kB)
# Collecting autogluon.tabular[all]==0.6.0
#   Using cached autogluon.tabular-0.6.0-py3-none-any.whl (285 kB)
# Collecting autogluon.text==0.6.0
#   Using cached autogluon.text-0.6.0-py3-none-any.whl (62 kB)
# Collecting autogluon.features==0.6.0
#   Using cached autogluon.features-0.6.0-py3-none-any.whl (59 kB)
# Collecting autogluon.multimodal==0.6.0
#   Using cached autogluon.multimodal-0.6.0-py3-none-any.whl (279 kB)
# Requirement already satisfied: scipy<1.10.0,>=1.5.4 in /Users/jarrycf/opt/anaconda3/lib/python3.9/site-packages (from autogluon.core[all]==0.6.0->autogluon) (1.8.1)
# Collecting autogluon.common==0.6.0
#   Using cached autogluon.common-0.6.0-py3-none-any.whl (41 kB)
# Requirement already satisfied: scikit-learn<1.2,>=1.0.0 in /Users/jarrycf/opt/anaconda3/lib/python3.9/site-packages (from autogluon.core[all]==0.6.0->autogluon) (1.1.1)
# Requirement already satisfied: numpy<1.24,>=1.21 in /Users/jarrycf/opt/anaconda3/lib/python3.9/site-packages (from autogluon.core[all]==0.6.0->autogluon) (1.21.5)
# Requirement already satisfied: boto3 in /Users/jarrycf/opt/anaconda3/lib/python3.9/site-packages (from autogluon.core[all]==0.6.0->autogluon) (1.24.28)
# Requirement already satisfied: dask<=2021.11.2,>=2021.09.1 in /Users/jarrycf/opt/anaconda3/lib/python3.9/site-packages (from autogluon.core[all]==0.6.0->autogluon) (2021.11.2)
# Requirement already satisfied: pandas!=1.4.0,<1.6,>=1.2.5 in /Users/jarrycf/opt/anaconda3/lib/python3.9/site-packages (from autogluon.core[all]==0.6.0->autogluon) (1.4.4)
# Requirement already satisfied: matplotlib in /Users/jarrycf/opt/anaconda3/lib/python3.9/site-packages (from autogluon.core[all]==0.6.0->autogluon) (3.5.2)
# Requirement already satisfied: tqdm>=4.38.0 in /Users/jarrycf/opt/anaconda3/lib/python3.9/site-packages (from autogluon.core[all]==0.6.0->autogluon) (4.64.1)
# Collecting distributed<=2021.11.2,>=2021.09.1
#   Using cached distributed-2021.11.2-py3-none-any.whl (802 kB)
# Requirement already satisfied: requests in /Users/jarrycf/opt/anaconda3/lib/python3.9/site-packages (from autogluon.core[all]==0.6.0->autogluon) (2.28.1)
# Requirement already satisfied: ray[tune]<2.1,>=2.0 in /Users/jarrycf/opt/anaconda3/lib/python3.9/site-packages (from autogluon.core[all]==0.6.0->autogluon) (2.0.1)
# Requirement already satisfied: hyperopt<0.2.8,>=0.2.7 in /Users/jarrycf/opt/anaconda3/lib/python3.9/site-packages (from autogluon.core[all]==0.6.0->autogluon) (0.2.7)
# Requirement already satisfied: psutil<6,>=5.7.3 in /Users/jarrycf/opt/anaconda3/lib/python3.9/site-packages (from autogluon.features==0.6.0->autogluon) (5.8.0)
# Requirement already satisfied: fairscale<=0.4.6,>=0.4.5 in /Users/jarrycf/opt/anaconda3/lib/python3.9/site-packages (from autogluon.multimodal==0.6.0->autogluon) (0.4.6)
# Requirement already satisfied: jsonschema<=4.8.0 in /Users/jarrycf/opt/anaconda3/lib/python3.9/site-packages (from autogluon.multimodal==0.6.0->autogluon) (4.8.0)
# Collecting evaluate<=0.2.2
#   Using cached evaluate-0.2.2-py3-none-any.whl (69 kB)
# Requirement already satisfied: torchmetrics<0.9.0,>=0.8.0 in /Users/jarrycf/opt/anaconda3/lib/python3.9/site-packages (from autogluon.multimodal==0.6.0->autogluon) (0.8.2)
# Requirement already satisfied: nlpaug<=1.1.10,>=1.1.10 in /Users/jarrycf/opt/anaconda3/lib/python3.9/site-packages (from autogluon.multimodal==0.6.0->autogluon) (1.1.10)
# Requirement already satisfied: openmim<=0.2.1,>0.1.5 in /Users/jarrycf/opt/anaconda3/lib/python3.9/site-packages (from autogluon.multimodal==0.6.0->autogluon) (0.2.1)
# Requirement already satisfied: sentencepiece<0.2.0,>=0.1.95 in /Users/jarrycf/opt/anaconda3/lib/python3.9/site-packages (from autogluon.multimodal==0.6.0->autogluon) (0.1.97)
# Collecting albumentations<=1.2.0,>=1.1.0
#   Using cached albumentations-1.2.0-py3-none-any.whl (113 kB)
# Requirement already satisfied: torch<1.13,>=1.9 in /Users/jarrycf/opt/anaconda3/lib/python3.9/site-packages (from autogluon.multimodal==0.6.0->autogluon) (1.12.1)
# Requirement already satisfied: transformers<4.24.0,>=4.23.0 in /Users/jarrycf/opt/anaconda3/lib/python3.9/site-packages (from autogluon.multimodal==0.6.0->autogluon) (4.23.1)
# Requirement already satisfied: torchvision<0.14.0 in /Users/jarrycf/opt/anaconda3/lib/python3.9/site-packages (from autogluon.multimodal==0.6.0->autogluon) (0.13.1)
# Requirement already satisfied: text-unidecode<=1.3 in /Users/jarrycf/opt/anaconda3/lib/python3.9/site-packages (from autogluon.multimodal==0.6.0->autogluon) (1.3)
# Collecting pytorch-lightning<1.8.0,>=1.7.4
#   Using cached pytorch_lightning-1.7.7-py3-none-any.whl (708 kB)
# Requirement already satisfied: defusedxml<=0.7.1,>=0.7.1 in /Users/jarrycf/opt/anaconda3/lib/python3.9/site-packages (from autogluon.multimodal==0.6.0->autogluon) (0.7.1)
# Requirement already satisfied: timm<0.7.0 in /Users/jarrycf/opt/anaconda3/lib/python3.9/site-packages (from autogluon.multimodal==0.6.0->autogluon) (0.6.12)
# Requirement already satisfied: pycocotools<2.0.7,>=2.0.5 in /Users/jarrycf/opt/anaconda3/lib/python3.9/site-packages (from autogluon.multimodal==0.6.0->autogluon) (2.0.6)
# Requirement already satisfied: pytorch-metric-learning<1.4.0,>=1.3.0 in /Users/jarrycf/opt/anaconda3/lib/python3.9/site-packages (from autogluon.multimodal==0.6.0->autogluon) (1.3.2)
# Requirement already satisfied: Pillow<9.1.0,>=9.0.1 in /Users/jarrycf/opt/anaconda3/lib/python3.9/site-packages (from autogluon.multimodal==0.6.0->autogluon) (9.0.1)
# Requirement already satisfied: torchtext<0.14.0 in /Users/jarrycf/opt/anaconda3/lib/python3.9/site-packages (from autogluon.multimodal==0.6.0->autogluon) (0.13.1)
# Requirement already satisfied: smart-open<5.3.0,>=5.2.1 in /Users/jarrycf/opt/anaconda3/lib/python3.9/site-packages (from autogluon.multimodal==0.6.0->autogluon) (5.2.1)
# Requirement already satisfied: accelerate<0.14,>=0.9 in /Users/jarrycf/opt/anaconda3/lib/python3.9/site-packages (from autogluon.multimodal==0.6.0->autogluon) (0.13.2)
# Requirement already satisfied: scikit-image<0.20.0,>=0.19.1 in /Users/jarrycf/opt/anaconda3/lib/python3.9/site-packages (from autogluon.multimodal==0.6.0->autogluon) (0.19.2)
# Requirement already satisfied: seqeval<=1.2.2 in /Users/jarrycf/opt/anaconda3/lib/python3.9/site-packages (from autogluon.multimodal==0.6.0->autogluon) (1.2.2)
# Requirement already satisfied: nptyping<1.5.0,>=1.4.4 in /Users/jarrycf/opt/anaconda3/lib/python3.9/site-packages (from autogluon.multimodal==0.6.0->autogluon) (1.4.4)
# Requirement already satisfied: omegaconf<2.2.0,>=2.1.1 in /Users/jarrycf/opt/anaconda3/lib/python3.9/site-packages (from autogluon.multimodal==0.6.0->autogluon) (2.1.2)
# Requirement already satisfied: nltk<4.0.0,>=3.4.5 in /Users/jarrycf/opt/anaconda3/lib/python3.9/site-packages (from autogluon.multimodal==0.6.0->autogluon) (3.7)
# Requirement already satisfied: networkx<3.0,>=2.3 in /Users/jarrycf/opt/anaconda3/lib/python3.9/site-packages (from autogluon.tabular[all]==0.6.0->autogluon) (2.8.4)
# Collecting catboost<1.2,>=1.0
#   Using cached catboost-1.1.1-cp39-none-macosx_10_6_universal2.whl (22.0 MB)
# Collecting fastai<2.8,>=2.3.1
#   Using cached fastai-2.7.10-py3-none-any.whl (240 kB)
# Collecting lightgbm<3.4,>=3.3
#   Using cached lightgbm-3.3.3.tar.gz (1.5 MB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: xgboost<1.8,>=1.6 in /Users/jarrycf/opt/anaconda3/lib/python3.9/site-packages (from autogluon.tabular[all]==0.6.0->autogluon) (1.7.1)
# Requirement already satisfied: statsmodels~=0.13.0 in /Users/jarrycf/opt/anaconda3/lib/python3.9/site-packages (from autogluon.timeseries[all]==0.6.0->autogluon) (0.13.2)
# Collecting gluonts~=0.11.0
#   Using cached gluonts-0.11.3-py3-none-any.whl (1.0 MB)
# Requirement already satisfied: joblib~=1.1 in /Users/jarrycf/opt/anaconda3/lib/python3.9/site-packages (from autogluon.timeseries[all]==0.6.0->autogluon) (1.1.0)
# Collecting tbats~=1.1
#   Using cached tbats-1.1.1-py3-none-any.whl (43 kB)
# Collecting pmdarima~=1.8.2
#   Using cached pmdarima-1.8.5-cp39-cp39-macosx_12_0_arm64.whl
# Collecting sktime<0.14,>=0.13.1
#   Using cached sktime-0.13.4-py3-none-any.whl (7.0 MB)
# Collecting gluoncv<0.10.6,>=0.10.5
#   Using cached gluoncv-0.10.5.post0-py2.py3-none-any.whl (1.3 MB)
# Requirement already satisfied: setuptools in /Users/jarrycf/opt/anaconda3/lib/python3.9/site-packages (from autogluon.common==0.6.0->autogluon.core[all]==0.6.0->autogluon) (63.4.1)
# Requirement already satisfied: pyyaml in /Users/jarrycf/opt/anaconda3/lib/python3.9/site-packages (from accelerate<0.14,>=0.9->autogluon.multimodal==0.6.0->autogluon) (6.0)
# Requirement already satisfied: packaging>=20.0 in /Users/jarrycf/opt/anaconda3/lib/python3.9/site-packages (from accelerate<0.14,>=0.9->autogluon.multimodal==0.6.0->autogluon) (21.3)
# Collecting albumentations<=1.2.0,>=1.1.0
#   Using cached albumentations-1.1.0-py3-none-any.whl (102 kB)
# Requirement already satisfied: opencv-python-headless>=4.1.1 in /Users/jarrycf/opt/anaconda3/lib/python3.9/site-packages (from albumentations<=1.2.0,>=1.1.0->autogluon.multimodal==0.6.0->autogluon) (4.6.0.66)
# Requirement already satisfied: qudida>=0.0.4 in /Users/jarrycf/opt/anaconda3/lib/python3.9/site-packages (from albumentations<=1.2.0,>=1.1.0->autogluon.multimodal==0.6.0->autogluon) (0.0.4)
# Requirement already satisfied: plotly in /Users/jarrycf/opt/anaconda3/lib/python3.9/site-packages (from catboost<1.2,>=1.0->autogluon.tabular[all]==0.6.0->autogluon) (5.9.0)
# Requirement already satisfied: six in /Users/jarrycf/opt/anaconda3/lib/python3.9/site-packages (from catboost<1.2,>=1.0->autogluon.tabular[all]==0.6.0->autogluon) (1.16.0)
# Requirement already satisfied: graphviz in /Users/jarrycf/opt/anaconda3/lib/python3.9/site-packages (from catboost<1.2,>=1.0->autogluon.tabular[all]==0.6.0->autogluon) (0.8.4)
# Requirement already satisfied: partd>=0.3.10 in /Users/jarrycf/opt/anaconda3/lib/python3.9/site-packages (from dask<=2021.11.2,>=2021.09.1->autogluon.core[all]==0.6.0->autogluon) (1.2.0)
# Requirement already satisfied: toolz>=0.8.2 in /Users/jarrycf/opt/anaconda3/lib/python3.9/site-packages (from dask<=2021.11.2,>=2021.09.1->autogluon.core[all]==0.6.0->autogluon) (0.11.2)
# Requirement already satisfied: fsspec>=0.6.0 in /Users/jarrycf/opt/anaconda3/lib/python3.9/site-packages (from dask<=2021.11.2,>=2021.09.1->autogluon.core[all]==0.6.0->autogluon) (2022.7.1)
# Requirement already satisfied: cloudpickle>=1.1.1 in /Users/jarrycf/opt/anaconda3/lib/python3.9/site-packages (from dask<=2021.11.2,>=2021.09.1->autogluon.core[all]==0.6.0->autogluon) (2.0.0)
# Requirement already satisfied: tornado>=6.0.3 in /Users/jarrycf/opt/anaconda3/lib/python3.9/site-packages (from distributed<=2021.11.2,>=2021.09.1->autogluon.core[all]==0.6.0->autogluon) (6.1)
# Requirement already satisfied: zict>=0.1.3 in /Users/jarrycf/opt/anaconda3/lib/python3.9/site-packages (from distributed<=2021.11.2,>=2021.09.1->autogluon.core[all]==0.6.0->autogluon) (2.1.0)
# Requirement already satisfied: sortedcontainers!=2.0.0,!=2.0.1 in /Users/jarrycf/opt/anaconda3/lib/python3.9/site-packages (from distributed<=2021.11.2,>=2021.09.1->autogluon.core[all]==0.6.0->autogluon) (2.4.0)
# Requirement already satisfied: click>=6.6 in /Users/jarrycf/opt/anaconda3/lib/python3.9/site-packages (from distributed<=2021.11.2,>=2021.09.1->autogluon.core[all]==0.6.0->autogluon) (8.0.4)
# Requirement already satisfied: jinja2 in /Users/jarrycf/opt/anaconda3/lib/python3.9/site-packages (from distributed<=2021.11.2,>=2021.09.1->autogluon.core[all]==0.6.0->autogluon) (2.11.3)
# Requirement already satisfied: tblib>=1.6.0 in /Users/jarrycf/opt/anaconda3/lib/python3.9/site-packages (from distributed<=2021.11.2,>=2021.09.1->autogluon.core[all]==0.6.0->autogluon) (1.7.0)
# Requirement already satisfied: msgpack>=0.6.0 in /Users/jarrycf/opt/anaconda3/lib/python3.9/site-packages (from distributed<=2021.11.2,>=2021.09.1->autogluon.core[all]==0.6.0->autogluon) (1.0.3)
# Collecting datasets>=2.0.0
#   Using cached datasets-2.7.1-py3-none-any.whl (451 kB)
# Requirement already satisfied: huggingface-hub>=0.7.0 in /Users/jarrycf/opt/anaconda3/lib/python3.9/site-packages (from evaluate<=0.2.2->autogluon.multimodal==0.6.0->autogluon) (0.11.0)
# Requirement already satisfied: responses<0.19 in /Users/jarrycf/opt/anaconda3/lib/python3.9/site-packages (from evaluate<=0.2.2->autogluon.multimodal==0.6.0->autogluon) (0.18.0)
# Requirement already satisfied: dill in /Users/jarrycf/opt/anaconda3/lib/python3.9/site-packages (from evaluate<=0.2.2->autogluon.multimodal==0.6.0->autogluon) (0.3.6)
# Requirement already satisfied: xxhash in /Users/jarrycf/opt/anaconda3/lib/python3.9/site-packages (from evaluate<=0.2.2->autogluon.multimodal==0.6.0->autogluon) (3.1.0)
# Requirement already satisfied: multiprocess in /Users/jarrycf/opt/anaconda3/lib/python3.9/site-packages (from evaluate<=0.2.2->autogluon.multimodal==0.6.0->autogluon) (0.70.14)
# Collecting fastdownload<2,>=0.0.5
#   Using cached fastdownload-0.0.7-py3-none-any.whl (12 kB)
# Requirement already satisfied: fastcore<1.6,>=1.4.5 in /Users/jarrycf/opt/anaconda3/lib/python3.9/site-packages (from fastai<2.8,>=2.3.1->autogluon.tabular[all]==0.6.0->autogluon) (1.5.27)
# Requirement already satisfied: pip in /Users/jarrycf/opt/anaconda3/lib/python3.9/site-packages (from fastai<2.8,>=2.3.1->autogluon.tabular[all]==0.6.0->autogluon) (22.2.2)
# Collecting spacy<4
#   Using cached spacy-3.4.3-cp39-cp39-macosx_11_0_arm64.whl (6.5 MB)
# Requirement already satisfied: fastprogress>=0.2.4 in /Users/jarrycf/opt/anaconda3/lib/python3.9/site-packages (from fastai<2.8,>=2.3.1->autogluon.tabular[all]==0.6.0->autogluon) (1.0.3)
# Requirement already satisfied: opencv-python in /Users/jarrycf/opt/anaconda3/lib/python3.9/site-packages (from gluoncv<0.10.6,>=0.10.5->autogluon.vision==0.6.0->autogluon) (4.6.0.66)
# Requirement already satisfied: autocfg in /Users/jarrycf/opt/anaconda3/lib/python3.9/site-packages (from gluoncv<0.10.6,>=0.10.5->autogluon.vision==0.6.0->autogluon) (0.0.8)
# Requirement already satisfied: yacs in /Users/jarrycf/opt/anaconda3/lib/python3.9/site-packages (from gluoncv<0.10.6,>=0.10.5->autogluon.vision==0.6.0->autogluon) (0.1.8)
# Requirement already satisfied: portalocker in /Users/jarrycf/opt/anaconda3/lib/python3.9/site-packages (from gluoncv<0.10.6,>=0.10.5->autogluon.vision==0.6.0->autogluon) (2.6.0)
# Requirement already satisfied: pydantic~=1.7 in /Users/jarrycf/opt/anaconda3/lib/python3.9/site-packages (from gluonts~=0.11.0->autogluon.timeseries[all]==0.6.0->autogluon) (1.10.2)
# Requirement already satisfied: typing-extensions~=4.0 in /Users/jarrycf/opt/anaconda3/lib/python3.9/site-packages (from gluonts~=0.11.0->autogluon.timeseries[all]==0.6.0->autogluon) (4.3.0)
# Requirement already satisfied: py4j in /Users/jarrycf/opt/anaconda3/lib/python3.9/site-packages (from hyperopt<0.2.8,>=0.2.7->autogluon.core[all]==0.6.0->autogluon) (0.10.9.7)
# Requirement already satisfied: future in /Users/jarrycf/opt/anaconda3/lib/python3.9/site-packages (from hyperopt<0.2.8,>=0.2.7->autogluon.core[all]==0.6.0->autogluon) (0.18.2)
# Requirement already satisfied: attrs>=17.4.0 in /Users/jarrycf/opt/anaconda3/lib/python3.9/site-packages (from jsonschema<=4.8.0->autogluon.multimodal==0.6.0->autogluon) (21.4.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /Users/jarrycf/opt/anaconda3/lib/python3.9/site-packages (from jsonschema<=4.8.0->autogluon.multimodal==0.6.0->autogluon) (0.18.0)
# Requirement already satisfied: wheel in /Users/jarrycf/opt/anaconda3/lib/python3.9/site-packages (from lightgbm<3.4,>=3.3->autogluon.tabular[all]==0.6.0->autogluon) (0.37.1)
# Requirement already satisfied: regex>=2021.8.3 in /Users/jarrycf/opt/anaconda3/lib/python3.9/site-packages (from nltk<4.0.0,>=3.4.5->autogluon.multimodal==0.6.0->autogluon) (2022.7.9)
# Requirement already satisfied: typish>=1.7.0 in /Users/jarrycf/opt/anaconda3/lib/python3.9/site-packages (from nptyping<1.5.0,>=1.4.4->autogluon.multimodal==0.6.0->autogluon) (1.9.3)
# Requirement already satisfied: antlr4-python3-runtime==4.8 in /Users/jarrycf/opt/anaconda3/lib/python3.9/site-packages (from omegaconf<2.2.0,>=2.1.1->autogluon.multimodal==0.6.0->autogluon) (4.8)
# Requirement already satisfied: colorama in /Users/jarrycf/opt/anaconda3/lib/python3.9/site-packages (from openmim<=0.2.1,>0.1.5->autogluon.multimodal==0.6.0->autogluon) (0.4.5)
# Requirement already satisfied: tabulate in /Users/jarrycf/opt/anaconda3/lib/python3.9/site-packages (from openmim<=0.2.1,>0.1.5->autogluon.multimodal==0.6.0->autogluon) (0.8.10)
# Requirement already satisfied: model-index in /Users/jarrycf/opt/anaconda3/lib/python3.9/site-packages (from openmim<=0.2.1,>0.1.5->autogluon.multimodal==0.6.0->autogluon) (0.1.11)
# Requirement already satisfied: rich in /Users/jarrycf/opt/anaconda3/lib/python3.9/site-packages (from openmim<=0.2.1,>0.1.5->autogluon.multimodal==0.6.0->autogluon) (12.6.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /Users/jarrycf/opt/anaconda3/lib/python3.9/site-packages (from pandas!=1.4.0,<1.6,>=1.2.5->autogluon.core[all]==0.6.0->autogluon) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/jarrycf/opt/anaconda3/lib/python3.9/site-packages (from pandas!=1.4.0,<1.6,>=1.2.5->autogluon.core[all]==0.6.0->autogluon) (2022.1)
# Requirement already satisfied: urllib3 in /Users/jarrycf/opt/anaconda3/lib/python3.9/site-packages (from pmdarima~=1.8.2->autogluon.timeseries[all]==0.6.0->autogluon) (1.26.11)
# Requirement already satisfied: Cython!=0.29.18,>=0.29 in /Users/jarrycf/opt/anaconda3/lib/python3.9/site-packages (from pmdarima~=1.8.2->autogluon.timeseries[all]==0.6.0->autogluon) (0.29.32)
# Requirement already satisfied: cycler>=0.10 in /Users/jarrycf/opt/anaconda3/lib/python3.9/site-packages (from matplotlib->autogluon.core[all]==0.6.0->autogluon) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/jarrycf/opt/anaconda3/lib/python3.9/site-packages (from matplotlib->autogluon.core[all]==0.6.0->autogluon) (1.4.2)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/jarrycf/opt/anaconda3/lib/python3.9/site-packages (from matplotlib->autogluon.core[all]==0.6.0->autogluon) (4.25.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /Users/jarrycf/opt/anaconda3/lib/python3.9/site-packages (from matplotlib->autogluon.core[all]==0.6.0->autogluon) (3.0.9)
# Collecting tensorboard>=2.9.1
#   Using cached tensorboard-2.11.0-py3-none-any.whl (6.0 MB)
# Requirement already satisfied: pyDeprecate>=0.3.1 in /Users/jarrycf/opt/anaconda3/lib/python3.9/site-packages (from pytorch-lightning<1.8.0,>=1.7.4->autogluon.multimodal==0.6.0->autogluon) (0.3.2)
# Requirement already satisfied: aiosignal in /Users/jarrycf/opt/anaconda3/lib/python3.9/site-packages (from ray[tune]<2.1,>=2.0->autogluon.core[all]==0.6.0->autogluon) (1.3.1)
# Requirement already satisfied: virtualenv in /Users/jarrycf/opt/anaconda3/lib/python3.9/site-packages (from ray[tune]<2.1,>=2.0->autogluon.core[all]==0.6.0->autogluon) (20.16.7)
# Requirement already satisfied: protobuf<4.0.0,>=3.15.3 in /Users/jarrycf/opt/anaconda3/lib/python3.9/site-packages (from ray[tune]<2.1,>=2.0->autogluon.core[all]==0.6.0->autogluon) (3.20.1)
# Requirement already satisfied: frozenlist in /Users/jarrycf/opt/anaconda3/lib/python3.9/site-packages (from ray[tune]<2.1,>=2.0->autogluon.core[all]==0.6.0->autogluon) (1.3.3)
# Requirement already satisfied: filelock in /Users/jarrycf/opt/anaconda3/lib/python3.9/site-packages (from ray[tune]<2.1,>=2.0->autogluon.core[all]==0.6.0->autogluon) (3.6.0)
# Requirement already satisfied: grpcio<=1.43.0,>=1.32.0 in /Users/jarrycf/opt/anaconda3/lib/python3.9/site-packages (from ray[tune]<2.1,>=2.0->autogluon.core[all]==0.6.0->autogluon) (1.43.0)
# Requirement already satisfied: tensorboardX>=1.9 in /Users/jarrycf/opt/anaconda3/lib/python3.9/site-packages (from ray[tune]<2.1,>=2.0->autogluon.core[all]==0.6.0->autogluon) (2.5.1)
# Requirement already satisfied: charset-normalizer<3,>=2 in /Users/jarrycf/opt/anaconda3/lib/python3.9/site-packages (from requests->autogluon.core[all]==0.6.0->autogluon) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/jarrycf/opt/anaconda3/lib/python3.9/site-packages (from requests->autogluon.core[all]==0.6.0->autogluon) (2022.9.24)
# Requirement already satisfied: idna<4,>=2.5 in /Users/jarrycf/opt/anaconda3/lib/python3.9/site-packages (from requests->autogluon.core[all]==0.6.0->autogluon) (3.3)
# Requirement already satisfied: PyWavelets>=1.1.1 in /Users/jarrycf/opt/anaconda3/lib/python3.9/site-packages (from scikit-image<0.20.0,>=0.19.1->autogluon.multimodal==0.6.0->autogluon) (1.3.0)
# Requirement already satisfied: tifffile>=2019.7.26 in /Users/jarrycf/opt/anaconda3/lib/python3.9/site-packages (from scikit-image<0.20.0,>=0.19.1->autogluon.multimodal==0.6.0->autogluon) (2021.7.2)
# Requirement already satisfied: imageio>=2.4.1 in /Users/jarrycf/opt/anaconda3/lib/python3.9/site-packages (from scikit-image<0.20.0,>=0.19.1->autogluon.multimodal==0.6.0->autogluon) (2.19.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/jarrycf/opt/anaconda3/lib/python3.9/site-packages (from scikit-learn<1.2,>=1.0.0->autogluon.core[all]==0.6.0->autogluon) (2.2.0)
# Requirement already satisfied: deprecated>=1.2.13 in /Users/jarrycf/opt/anaconda3/lib/python3.9/site-packages (from sktime<0.14,>=0.13.1->autogluon.timeseries[all]==0.6.0->autogluon) (1.2.13)
# Requirement already satisfied: numba>=0.53 in /Users/jarrycf/opt/anaconda3/lib/python3.9/site-packages (from sktime<0.14,>=0.13.1->autogluon.timeseries[all]==0.6.0->autogluon) (0.55.1)
# Requirement already satisfied: patsy>=0.5.2 in /Users/jarrycf/opt/anaconda3/lib/python3.9/site-packages (from statsmodels~=0.13.0->autogluon.timeseries[all]==0.6.0->autogluon) (0.5.2)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /Users/jarrycf/opt/anaconda3/lib/python3.9/site-packages (from transformers<4.24.0,>=4.23.0->autogluon.multimodal==0.6.0->autogluon) (0.13.2)
# Requirement already satisfied: s3transfer<0.7.0,>=0.6.0 in /Users/jarrycf/opt/anaconda3/lib/python3.9/site-packages (from boto3->autogluon.core[all]==0.6.0->autogluon) (0.6.0)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /Users/jarrycf/opt/anaconda3/lib/python3.9/site-packages (from boto3->autogluon.core[all]==0.6.0->autogluon) (0.10.0)
# Requirement already satisfied: botocore<1.28.0,>=1.27.28 in /Users/jarrycf/opt/anaconda3/lib/python3.9/site-packages (from boto3->autogluon.core[all]==0.6.0->autogluon) (1.27.28)
# Requirement already satisfied: pyarrow>=6.0.0 in /Users/jarrycf/opt/anaconda3/lib/python3.9/site-packages (from datasets>=2.0.0->evaluate<=0.2.2->autogluon.multimodal==0.6.0->autogluon) (10.0.1)
# Requirement already satisfied: aiohttp in /Users/jarrycf/opt/anaconda3/lib/python3.9/site-packages (from datasets>=2.0.0->evaluate<=0.2.2->autogluon.multimodal==0.6.0->autogluon) (3.8.3)
# Requirement already satisfied: wrapt<2,>=1.10 in /Users/jarrycf/opt/anaconda3/lib/python3.9/site-packages (from deprecated>=1.2.13->sktime<0.14,>=0.13.1->autogluon.timeseries[all]==0.6.0->autogluon) (1.14.1)
# Requirement already satisfied: llvmlite<0.39,>=0.38.0rc1 in /Users/jarrycf/opt/anaconda3/lib/python3.9/site-packages (from numba>=0.53->sktime<0.14,>=0.13.1->autogluon.timeseries[all]==0.6.0->autogluon) (0.38.0)
# Requirement already satisfied: locket in /Users/jarrycf/opt/anaconda3/lib/python3.9/site-packages (from partd>=0.3.10->dask<=2021.11.2,>=2021.09.1->autogluon.core[all]==0.6.0->autogluon) (1.0.0)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /Users/jarrycf/opt/anaconda3/lib/python3.9/site-packages (from spacy<4->fastai<2.8,>=2.3.1->autogluon.tabular[all]==0.6.0->autogluon) (2.4.5)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /Users/jarrycf/opt/anaconda3/lib/python3.9/site-packages (from spacy<4->fastai<2.8,>=2.3.1->autogluon.tabular[all]==0.6.0->autogluon) (2.0.7)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /Users/jarrycf/opt/anaconda3/lib/python3.9/site-packages (from spacy<4->fastai<2.8,>=2.3.1->autogluon.tabular[all]==0.6.0->autogluon) (1.0.9)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.10 in /Users/jarrycf/opt/anaconda3/lib/python3.9/site-packages (from spacy<4->fastai<2.8,>=2.3.1->autogluon.tabular[all]==0.6.0->autogluon) (3.0.10)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /Users/jarrycf/opt/anaconda3/lib/python3.9/site-packages (from spacy<4->fastai<2.8,>=2.3.1->autogluon.tabular[all]==0.6.0->autogluon) (3.0.8)
# Requirement already satisfied: pathy>=0.3.5 in /Users/jarrycf/opt/anaconda3/lib/python3.9/site-packages (from spacy<4->fastai<2.8,>=2.3.1->autogluon.tabular[all]==0.6.0->autogluon) (0.10.0)
# Requirement already satisfied: thinc<8.2.0,>=8.1.0 in /Users/jarrycf/opt/anaconda3/lib/python3.9/site-packages (from spacy<4->fastai<2.8,>=2.3.1->autogluon.tabular[all]==0.6.0->autogluon) (8.1.5)
# Requirement already satisfied: typer<0.8.0,>=0.3.0 in /Users/jarrycf/opt/anaconda3/lib/python3.9/site-packages (from spacy<4->fastai<2.8,>=2.3.1->autogluon.tabular[all]==0.6.0->autogluon) (0.7.0)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /Users/jarrycf/opt/anaconda3/lib/python3.9/site-packages (from spacy<4->fastai<2.8,>=2.3.1->autogluon.tabular[all]==0.6.0->autogluon) (1.0.3)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /Users/jarrycf/opt/anaconda3/lib/python3.9/site-packages (from spacy<4->fastai<2.8,>=2.3.1->autogluon.tabular[all]==0.6.0->autogluon) (2.0.8)
# Requirement already satisfied: wasabi<1.1.0,>=0.9.1 in /Users/jarrycf/opt/anaconda3/lib/python3.9/site-packages (from spacy<4->fastai<2.8,>=2.3.1->autogluon.tabular[all]==0.6.0->autogluon) (0.10.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /Users/jarrycf/opt/anaconda3/lib/python3.9/site-packages (from spacy<4->fastai<2.8,>=2.3.1->autogluon.tabular[all]==0.6.0->autogluon) (3.3.0)
# Requirement already satisfied: absl-py>=0.4 in /Users/jarrycf/opt/anaconda3/lib/python3.9/site-packages (from tensorboard>=2.9.1->pytorch-lightning<1.8.0,>=1.7.4->autogluon.multimodal==0.6.0->autogluon) (1.3.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /Users/jarrycf/opt/anaconda3/lib/python3.9/site-packages (from tensorboard>=2.9.1->pytorch-lightning<1.8.0,>=1.7.4->autogluon.multimodal==0.6.0->autogluon) (1.8.1)
# Requirement already satisfied: markdown>=2.6.8 in /Users/jarrycf/opt/anaconda3/lib/python3.9/site-packages (from tensorboard>=2.9.1->pytorch-lightning<1.8.0,>=1.7.4->autogluon.multimodal==0.6.0->autogluon) (3.3.4)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /Users/jarrycf/opt/anaconda3/lib/python3.9/site-packages (from tensorboard>=2.9.1->pytorch-lightning<1.8.0,>=1.7.4->autogluon.multimodal==0.6.0->autogluon) (0.6.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /Users/jarrycf/opt/anaconda3/lib/python3.9/site-packages (from tensorboard>=2.9.1->pytorch-lightning<1.8.0,>=1.7.4->autogluon.multimodal==0.6.0->autogluon) (2.0.3)
# Collecting google-auth-oauthlib<0.5,>=0.4.1
#   Using cached google_auth_oauthlib-0.4.6-py2.py3-none-any.whl (18 kB)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /Users/jarrycf/opt/anaconda3/lib/python3.9/site-packages (from tensorboard>=2.9.1->pytorch-lightning<1.8.0,>=1.7.4->autogluon.multimodal==0.6.0->autogluon) (2.14.1)
# Requirement already satisfied: heapdict in /Users/jarrycf/opt/anaconda3/lib/python3.9/site-packages (from zict>=0.1.3->distributed<=2021.11.2,>=2021.09.1->autogluon.core[all]==0.6.0->autogluon) (1.0.1)
# Requirement already satisfied: MarkupSafe>=0.23 in /Users/jarrycf/opt/anaconda3/lib/python3.9/site-packages (from jinja2->distributed<=2021.11.2,>=2021.09.1->autogluon.core[all]==0.6.0->autogluon) (2.0.1)
# Requirement already satisfied: ordered-set in /Users/jarrycf/opt/anaconda3/lib/python3.9/site-packages (from model-index->openmim<=0.2.1,>0.1.5->autogluon.multimodal==0.6.0->autogluon) (4.1.0)
# Requirement already satisfied: tenacity>=6.2.0 in /Users/jarrycf/opt/anaconda3/lib/python3.9/site-packages (from plotly->catboost<1.2,>=1.0->autogluon.tabular[all]==0.6.0->autogluon) (8.0.1)
# Requirement already satisfied: commonmark<0.10.0,>=0.9.0 in /Users/jarrycf/opt/anaconda3/lib/python3.9/site-packages (from rich->openmim<=0.2.1,>0.1.5->autogluon.multimodal==0.6.0->autogluon) (0.9.1)
# Requirement already satisfied: pygments<3.0.0,>=2.6.0 in /Users/jarrycf/opt/anaconda3/lib/python3.9/site-packages (from rich->openmim<=0.2.1,>0.1.5->autogluon.multimodal==0.6.0->autogluon) (2.11.2)
# Requirement already satisfied: distlib<1,>=0.3.6 in /Users/jarrycf/opt/anaconda3/lib/python3.9/site-packages (from virtualenv->ray[tune]<2.1,>=2.0->autogluon.core[all]==0.6.0->autogluon) (0.3.6)
# Requirement already satisfied: platformdirs<3,>=2.4 in /Users/jarrycf/opt/anaconda3/lib/python3.9/site-packages (from virtualenv->ray[tune]<2.1,>=2.0->autogluon.core[all]==0.6.0->autogluon) (2.5.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Users/jarrycf/opt/anaconda3/lib/python3.9/site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->pytorch-lightning<1.8.0,>=1.7.4->autogluon.multimodal==0.6.0->autogluon) (4.9)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/jarrycf/opt/anaconda3/lib/python3.9/site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->pytorch-lightning<1.8.0,>=1.7.4->autogluon.multimodal==0.6.0->autogluon) (0.2.8)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /Users/jarrycf/opt/anaconda3/lib/python3.9/site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->pytorch-lightning<1.8.0,>=1.7.4->autogluon.multimodal==0.6.0->autogluon) (5.2.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /Users/jarrycf/opt/anaconda3/lib/python3.9/site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.9.1->pytorch-lightning<1.8.0,>=1.7.4->autogluon.multimodal==0.6.0->autogluon) (1.3.1)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /Users/jarrycf/opt/anaconda3/lib/python3.9/site-packages (from thinc<8.2.0,>=8.1.0->spacy<4->fastai<2.8,>=2.3.1->autogluon.tabular[all]==0.6.0->autogluon) (0.7.9)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /Users/jarrycf/opt/anaconda3/lib/python3.9/site-packages (from thinc<8.2.0,>=8.1.0->spacy<4->fastai<2.8,>=2.3.1->autogluon.tabular[all]==0.6.0->autogluon) (0.0.3)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/jarrycf/opt/anaconda3/lib/python3.9/site-packages (from aiohttp->datasets>=2.0.0->evaluate<=0.2.2->autogluon.multimodal==0.6.0->autogluon) (6.0.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in /Users/jarrycf/opt/anaconda3/lib/python3.9/site-packages (from aiohttp->datasets>=2.0.0->evaluate<=0.2.2->autogluon.multimodal==0.6.0->autogluon) (1.8.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /Users/jarrycf/opt/anaconda3/lib/python3.9/site-packages (from aiohttp->datasets>=2.0.0->evaluate<=0.2.2->autogluon.multimodal==0.6.0->autogluon) (4.0.2)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /Users/jarrycf/opt/anaconda3/lib/python3.9/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard>=2.9.1->pytorch-lightning<1.8.0,>=1.7.4->autogluon.multimodal==0.6.0->autogluon) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /Users/jarrycf/opt/anaconda3/lib/python3.9/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.9.1->pytorch-lightning<1.8.0,>=1.7.4->autogluon.multimodal==0.6.0->autogluon) (3.2.2)
# Building wheels for collected packages: lightgbm
#   Building wheel for lightgbm (setup.py) ... error
#   error: subprocess-exited-with-error
#
#   × python setup.py bdist_wheel did not run successfully.
#   │ exit code: 1
#   ╰─> [86 lines of output]
#       running bdist_wheel
#       /Users/jarrycf/opt/anaconda3/lib/python3.9/site-packages/setuptools/command/install.py:34: SetuptoolsDeprecationWarning: setup.py install is deprecated. Use build and pip and other standards-based tools.
#         warnings.warn(
#       running build
#       running build_py
#       creating build
#       creating build/lib
#       creating build/lib/lightgbm
#       copying lightgbm/callback.py -> build/lib/lightgbm
#       copying lightgbm/compat.py -> build/lib/lightgbm
#       copying lightgbm/plotting.py -> build/lib/lightgbm
#       copying lightgbm/__init__.py -> build/lib/lightgbm
#       copying lightgbm/engine.py -> build/lib/lightgbm
#       copying lightgbm/dask.py -> build/lib/lightgbm
#       copying lightgbm/basic.py -> build/lib/lightgbm
#       copying lightgbm/libpath.py -> build/lib/lightgbm
#       copying lightgbm/sklearn.py -> build/lib/lightgbm
#       running egg_info
#       writing lightgbm.egg-info/PKG-INFO
#       writing dependency_links to lightgbm.egg-info/dependency_links.txt
#       writing requirements to lightgbm.egg-info/requires.txt
#       writing top-level names to lightgbm.egg-info/top_level.txt
#       reading manifest file 'lightgbm.egg-info/SOURCES.txt'
#       reading manifest template 'MANIFEST.in'
#       no previously-included directories found matching 'build'
#       warning: no files found matching '*.so' under directory 'lightgbm'
#       warning: no files found matching '*.so' under directory 'compile'
#       warning: no files found matching '*.dll' under directory 'compile/Release'
#       warning: no files found matching '*.dll' under directory 'compile/windows/x64/DLL'
#       warning: no previously-included files matching '*.py[co]' found anywhere in distribution
#       warning: no previously-included files found matching 'compile/external_libs/compute/.git'
#       adding license file 'LICENSE'
#       writing manifest file 'lightgbm.egg-info/SOURCES.txt'
#       copying lightgbm/VERSION.txt -> build/lib/lightgbm
#       installing to build/bdist.macosx-11.1-arm64/wheel
#       running install
#       INFO:LightGBM:Starting to compile the library.
#       INFO:LightGBM:Starting to compile with CMake.
#       Traceback (most recent call last):
#         File "/private/var/folders/s5/8h2fbl8j7pj302ljpwfz6sf40000gn/T/pip-install-h68n4809/lightgbm_9b001e2cd6b84fd6b8d1c0c18c08c45c/setup.py", line 95, in silent_call
#           subprocess.check_call(cmd, stderr=log, stdout=log)
#         File "/Users/jarrycf/opt/anaconda3/lib/python3.9/subprocess.py", line 368, in check_call
#           retcode = call(*popenargs, **kwargs)
#         File "/Users/jarrycf/opt/anaconda3/lib/python3.9/subprocess.py", line 349, in call
#           with Popen(*popenargs, **kwargs) as p:
#         File "/Users/jarrycf/opt/anaconda3/lib/python3.9/subprocess.py", line 951, in __init__
#           self._execute_child(args, executable, preexec_fn, close_fds,
#         File "/Users/jarrycf/opt/anaconda3/lib/python3.9/subprocess.py", line 1821, in _execute_child
#           raise child_exception_type(errno_num, err_msg, err_filename)
#       FileNotFoundError: [Errno 2] No such file or directory: 'cmake'
#
#       During handling of the above exception, another exception occurred:
#
#       Traceback (most recent call last):
#         File "<string>", line 2, in <module>
#         File "<pip-setuptools-caller>", line 34, in <module>
#         File "/private/var/folders/s5/8h2fbl8j7pj302ljpwfz6sf40000gn/T/pip-install-h68n4809/lightgbm_9b001e2cd6b84fd6b8d1c0c18c08c45c/setup.py", line 334, in <module>
#           setup(name='lightgbm',
#         File "/Users/jarrycf/opt/anaconda3/lib/python3.9/site-packages/setuptools/__init__.py", line 87, in setup
#           return distutils.core.setup(**attrs)
#         File "/Users/jarrycf/opt/anaconda3/lib/python3.9/site-packages/setuptools/_distutils/core.py", line 185, in setup
#           return run_commands(dist)
#         File "/Users/jarrycf/opt/anaconda3/lib/python3.9/site-packages/setuptools/_distutils/core.py", line 201, in run_commands
#           dist.run_commands()
#         File "/Users/jarrycf/opt/anaconda3/lib/python3.9/site-packages/setuptools/_distutils/dist.py", line 973, in run_commands
#           self.run_command(cmd)
#         File "/Users/jarrycf/opt/anaconda3/lib/python3.9/site-packages/setuptools/dist.py", line 1217, in run_command
#           super().run_command(command)
#         File "/Users/jarrycf/opt/anaconda3/lib/python3.9/site-packages/setuptools/_distutils/dist.py", line 992, in run_command
#           cmd_obj.run()
#         File "/Users/jarrycf/opt/anaconda3/lib/python3.9/site-packages/wheel/bdist_wheel.py", line 335, in run
#           self.run_command('install')
#         File "/Users/jarrycf/opt/anaconda3/lib/python3.9/site-packages/setuptools/_distutils/cmd.py", line 319, in run_command
#           self.distribution.run_command(command)
#         File "/Users/jarrycf/opt/anaconda3/lib/python3.9/site-packages/setuptools/dist.py", line 1217, in run_command
#           super().run_command(command)
#         File "/Users/jarrycf/opt/anaconda3/lib/python3.9/site-packages/setuptools/_distutils/dist.py", line 992, in run_command
#           cmd_obj.run()
#         File "/private/var/folders/s5/8h2fbl8j7pj302ljpwfz6sf40000gn/T/pip-install-h68n4809/lightgbm_9b001e2cd6b84fd6b8d1c0c18c08c45c/setup.py", line 248, in run
#           compile_cpp(use_mingw=self.mingw, use_gpu=self.gpu, use_cuda=self.cuda, use_mpi=self.mpi,
#         File "/private/var/folders/s5/8h2fbl8j7pj302ljpwfz6sf40000gn/T/pip-install-h68n4809/lightgbm_9b001e2cd6b84fd6b8d1c0c18c08c45c/setup.py", line 198, in compile_cpp
#           silent_call(cmake_cmd, raise_error=True, error_msg='Please install CMake and all required dependencies first')
#         File "/private/var/folders/s5/8h2fbl8j7pj302ljpwfz6sf40000gn/T/pip-install-h68n4809/lightgbm_9b001e2cd6b84fd6b8d1c0c18c08c45c/setup.py", line 99, in silent_call
#           raise Exception("\n".join((error_msg, LOG_NOTICE)))
#       Exception: Please install CMake and all required dependencies first
#       The full version of error log was saved into /Users/jarrycf/LightGBM_compilation.log
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed building wheel for lightgbm
#   Running setup.py clean for lightgbm
# Failed to build lightgbm
# Installing collected packages: lightgbm, google-auth-oauthlib, gluonts, gluoncv, fastdownload, distributed, catboost, tensorboard, spacy, sktime, pmdarima, datasets, albumentations, tbats, pytorch-lightning, fastai, evaluate, autogluon.common, autogluon.features, autogluon.core, autogluon.tabular, autogluon.multimodal, autogluon.vision, autogluon.timeseries, autogluon.text, autogluon
#   Running setup.py install for lightgbm ... error
#   error: subprocess-exited-with-error
#
#   × Running setup.py install for lightgbm did not run successfully.
#   │ exit code: 1
#   ╰─> [45 lines of output]
#       running install
#       /Users/jarrycf/opt/anaconda3/lib/python3.9/site-packages/setuptools/command/install.py:34: SetuptoolsDeprecationWarning: setup.py install is deprecated. Use build and pip and other standards-based tools.
#         warnings.warn(
#       INFO:LightGBM:Starting to compile the library.
#       INFO:LightGBM:Starting to compile with CMake.
#       Traceback (most recent call last):
#         File "/private/var/folders/s5/8h2fbl8j7pj302ljpwfz6sf40000gn/T/pip-install-h68n4809/lightgbm_9b001e2cd6b84fd6b8d1c0c18c08c45c/setup.py", line 95, in silent_call
#           subprocess.check_call(cmd, stderr=log, stdout=log)
#         File "/Users/jarrycf/opt/anaconda3/lib/python3.9/subprocess.py", line 368, in check_call
#           retcode = call(*popenargs, **kwargs)
#         File "/Users/jarrycf/opt/anaconda3/lib/python3.9/subprocess.py", line 349, in call
#           with Popen(*popenargs, **kwargs) as p:
#         File "/Users/jarrycf/opt/anaconda3/lib/python3.9/subprocess.py", line 951, in __init__
#           self._execute_child(args, executable, preexec_fn, close_fds,
#         File "/Users/jarrycf/opt/anaconda3/lib/python3.9/subprocess.py", line 1821, in _execute_child
#           raise child_exception_type(errno_num, err_msg, err_filename)
#       FileNotFoundError: [Errno 2] No such file or directory: 'cmake'
#
#       During handling of the above exception, another exception occurred:
#
#       Traceback (most recent call last):
#         File "<string>", line 2, in <module>
#         File "<pip-setuptools-caller>", line 34, in <module>
#         File "/private/var/folders/s5/8h2fbl8j7pj302ljpwfz6sf40000gn/T/pip-install-h68n4809/lightgbm_9b001e2cd6b84fd6b8d1c0c18c08c45c/setup.py", line 334, in <module>
#           setup(name='lightgbm',
#         File "/Users/jarrycf/opt/anaconda3/lib/python3.9/site-packages/setuptools/__init__.py", line 87, in setup
#           return distutils.core.setup(**attrs)
#         File "/Users/jarrycf/opt/anaconda3/lib/python3.9/site-packages/setuptools/_distutils/core.py", line 185, in setup
#           return run_commands(dist)
#         File "/Users/jarrycf/opt/anaconda3/lib/python3.9/site-packages/setuptools/_distutils/core.py", line 201, in run_commands
#           dist.run_commands()
#         File "/Users/jarrycf/opt/anaconda3/lib/python3.9/site-packages/setuptools/_distutils/dist.py", line 973, in run_commands
#           self.run_command(cmd)
#         File "/Users/jarrycf/opt/anaconda3/lib/python3.9/site-packages/setuptools/dist.py", line 1217, in run_command
#           super().run_command(command)
#         File "/Users/jarrycf/opt/anaconda3/lib/python3.9/site-packages/setuptools/_distutils/dist.py", line 992, in run_command
#           cmd_obj.run()
#         File "/private/var/folders/s5/8h2fbl8j7pj302ljpwfz6sf40000gn/T/pip-install-h68n4809/lightgbm_9b001e2cd6b84fd6b8d1c0c18c08c45c/setup.py", line 248, in run
#           compile_cpp(use_mingw=self.mingw, use_gpu=self.gpu, use_cuda=self.cuda, use_mpi=self.mpi,
#         File "/private/var/folders/s5/8h2fbl8j7pj302ljpwfz6sf40000gn/T/pip-install-h68n4809/lightgbm_9b001e2cd6b84fd6b8d1c0c18c08c45c/setup.py", line 198, in compile_cpp
#           silent_call(cmake_cmd, raise_error=True, error_msg='Please install CMake and all required dependencies first')
#         File "/private/var/folders/s5/8h2fbl8j7pj302ljpwfz6sf40000gn/T/pip-install-h68n4809/lightgbm_9b001e2cd6b84fd6b8d1c0c18c08c45c/setup.py", line 99, in silent_call
#           raise Exception("\n".join((error_msg, LOG_NOTICE)))
#       Exception: Please install CMake and all required dependencies first
#       The full version of error log was saved into /Users/jarrycf/LightGBM_compilation.log
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: legacy-install-failure
#
# × Encountered error while trying to install package.
# ╰─> lightgbm
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for output from the failure.

# %%
from autogluon.tabular import TabularDataset, TabularPredictor
from sklearn.model_selection import train_test_split
import pandas as pd

data = pd.read_csv('./data/House_Training_index.csv')
train_data, test_data = train_test_split(data, 
test_size = 0.2, random_state=0)

#训练
train_data = TabularDataset(train_data)
id, label ='index', 'Y house price of unit area'
# 数据预处理
large_val_cols = ['X1 transaction date', 'X2 house age', 
                  'X3 distance to the nearest MRT station', 
                  'X4 number of convenience stores', 
                  'X5 latitude',
                  'X6 longitude']

for c in large_val_cols + [label]:
    train_data[c] = np.log(train_data[c] + 1)

                                                    
predictor = TabularPredictor(label=label).fit(train_data.drop(columns=[id]))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [2], in <cell line: 1>()
# ----> 1 from autogluon.tabular import TabularDataset, TabularPredictor
#       2 #训练
#       3 train_data = TabularDataset('./data/House_Training_index.csv')
#
# ModuleNotFoundError: No module named 'autogluon'

# %%
import pandas as pd

# %%
# 预测
test_data = TabularDataset(test_data）
preds = predictor.predict(test_data.drop(columns=[id])）
submission = pd.DataFrame({id:test_datal[id], label:preds})
submission.to_csv('submission.csv', index=False)
